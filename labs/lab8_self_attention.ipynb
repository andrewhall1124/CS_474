# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/porterjenkins/byu-cs474/blob/master/lab8_self_attention.ipynb)

# %% [markdown]
# # The Transformer and Attention
#
# In this lab, you will create a transformer. We will be performing the same task as the RNN lab: generating text using a decoder-only scheme. Instead of a character-by-character approach, we will do token-by-token (which is similar to word-by-word) generation.

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762)
# Note: these use the encoder-decoder approach. This is only necessary if we have a separate input and output sequence, like in a translation task. Here, our input and output sequence are the same, therefore we will use a decoder-only approach.
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import math, copy, time, collections

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on {}".format(device))
# Out:
# Running on cuda

# %% [markdown]
# ---
#
# # Examining the Dataset
#
# As always, we will begin by examining our data.
#
# Since we are performing the same task as the previous lab, we can use the same dataset.

# %%
# !pip install unidecode
import unidecode

# !wget -q --show-progress -O ./text_files.tar.gz 'https://piazza.com/redirect/s3?bucket=uploads&prefix=attach%2Fjlifkda6h0x5bk%2Fhzosotq4zil49m%2Fjn13x09arfeb%2Ftext_files.tar.gz'
# !tar -xzf text_files.tar.gz
file = unidecode.unidecode(open('./text_files/lotr.txt').read())

print(f"'file' is of type {type(file)} and contains {len(file)} characters\n")
# Out:
# Requirement already satisfied: unidecode in /home/andrew/miniconda3/lib/python3.12/site-packages (1.3.8)
# ./text_files.tar.gz 100%[===================>]   1.46M  --.-KB/s    in 0.1s
# 'file' is of type <class 'str'> and contains 2579888 characters

# %% [markdown]
# ## Tokenization
#
# Unlike last lab, we don't want to process our input character-by-character. Characters generally don't contain much semantic meaning, while words do. To use words as the base unit for our model, we need to separate the text into a sequence of words. We'll use the `spaCy` library to tokenize our text so we don't have to.
#
# **NOTE:** If you were using a non-English language corpus, this lab should work just fine, but you will need to find a language-appropriate spaCy model.

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy
# Out:
# Requirement already satisfied: spacy in /home/andrew/miniconda3/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (4.66.4)
# Requirement already satisfied: numpy>=1.19.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (2.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /home/andrew/miniconda3/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/andrew/miniconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/andrew/miniconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/andrew/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/andrew/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/andrew/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/andrew/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/andrew/miniconda3/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/andrew/miniconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/andrew/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /home/andrew/miniconda3/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/andrew/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 30.1 MB/s eta 0:00:00 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
spacy_model = spacy.load('en_core_web_sm')
def tokenize(line):
  return [tok.text for tok in spacy_model.tokenizer(line)]

# %% [markdown]
# Now lets tokenize the whole file and print out random sections of tokens.

# %%
all_tokens = tokenize(file)
print("The file is {} tokens long".format(len(all_tokens)))
# Out:
# The file is 618270 tokens long

# %%
seq_len_words = 30
for _ in range(4):
  i = np.random.randint(len(all_tokens) - seq_len_words)
  seq = all_tokens[i:i+seq_len_words]
  print(seq)
  print(' '.join(seq))
  print()
# Out:
# ['Ring', 'is', 'not', 'Frodo', ',', 'but', 'the', 'master', 'of', 'the', 'Dark', 'Tower', 'of', '\n', 'Mordor', ',', 'whose', 'power', 'is', 'again', 'stretching', 'out', 'over', 'the', 'world', '!', 'We', 'are', 'sitting', '\n']
# Ring is not Frodo , but the master of the Dark Tower of
#  Mordor , whose power is again stretching out over the world ! We are sitting
#
#
# ['up', 'through', 'the', '\n', 'branches', '.', "'", 'There', 'was', 'something', 'in', 'this', 'tree', 'that', 'I', 'have', 'never', 'seen', 'before', ',', "'", '\n', 'he', 'said', '.', "'", 'It', 'was', 'not', 'an']
# up through the
#  branches . ' There was something in this tree that I have never seen before , '
#  he said . ' It was not an
#
# ['make', 'me', 'regret', 'that', 'I', 'have', 'not', 'seen', 'these', 'caves', '.', '\n', 'Come', '!', 'Let', 'us', 'make', 'this', 'bargain', '-', 'if', 'we', 'both', 'return', 'safe', 'out', 'of', 'the', 'perils', 'that']
# make me regret that I have not seen these caves .
#  Come ! Let us make this bargain - if we both return safe out of the perils that
#
# ['in', 'Spring', ',', 'the', 'woods', 'and', 'fields', 'are', 'full', 'of', 'flowers', '.', 'But', '\n', 'maybe', 'we', 'will', 'go', 'thither', 'together', 'yet', '.', 'They', 'will', 'never', 'overcome', 'our', 'Lord', ',', '\n']
# in Spring , the woods and fields are full of flowers . But
#  maybe we will go thither together yet . They will never overcome our Lord ,

# %% [markdown]
# We are using a simple tokenizer, which mostly just splits at word boundaries, but also splits off punctuation and some compound words ("don't" is tokenized as "do", "n't"). More complex tokenizers may split parts of words as well (separating roots, prefixes, and suffixes).

# %% [markdown]
# Like in the RNN lab, we can't use these tokens as input to our model yet: we need to turn them into numerical data.
# Eventually we'll use word embeddings (`nn.Embedding`), but for now, we can turn them into indices for our embedding layer.
# We can build a vocabulary using the tokens in our corpus.
# Any word that appears less than `MIN_FREQ` times will be interpreted as an `<UNK>` (unknown) token, as we shouldn't expect our model to learn such an infrequent token.
# Even if we set `MIN_FREQ=1`, our model can encounter new tokens after training.

# %% [markdown]
# We have provided a custom vocabulary class. This is based on the functionality of torchtext.vocab, but torchtext is depreciated and cannot be imported with newer versions of PyTorch.

# %%
class Vocab:
    def __init__(self, tokens, special_tokens=['<UNK>'], min_freq=0, default_token='<UNK>'):
        counter = collections.Counter()
        counter.update(tokens)
        self.vocab_list = [token for token, count in counter.items() if count >= min_freq]
        if default_token not in special_tokens:
            special_tokens.append(default_token)
        self.vocab_list += special_tokens
        # Reverse vocab list w/ dictionary
        self.vocab_dict = dict([(token, i) for i, token in enumerate(self.vocab_list)])
        self.default_idx = self.vocab_dict[default_token]

    def idx_to_token(self, i):
        return self.vocab_list[i]

    def idx_tensor_to_tokens(self, indices):
        return [self.vocab_list[i.item()] for i in indices]

    def token_to_idx(self, token):
        try:
            return self.vocab_dict[token]
        except KeyError:
            return self.default_idx

    def tokens_to_idx_list(self, text):
        return [self.token_to_idx(token) for token in text]

    def __len__(self):
        return len(self.vocab_list)

# %%
UNK_TOKEN = '<UNK>'
vocab = Vocab(all_tokens, [UNK_TOKEN], min_freq=2, default_token=UNK_TOKEN)
print("Vocabulary contains {} unique tokens.".format(len(vocab)))
# Out:
# Vocabulary contains 9523 unique tokens.

# %% [markdown]
# This vocab object gives us a dictionary that we can use to transform tokens between string and integer representations.

# %%
print(f"Token Index {5} => {vocab.idx_to_token(5)}")
print(f"Token RINGS => {vocab.token_to_idx('RINGS')}")
# Out:
# Token Index 5 => RINGS
# Token RINGS => 5

# %% [markdown]
# Note that the vocabulary is case-sensitive. For the Lord of the Rings corpus, "Gandalf" is in the vocabulary, but "gandalf" is not and defaults to the "\<UNK\>" token.

# %%
print("Gandalf => {} ({})".format(vocab.idx_to_token(vocab.token_to_idx('Gandalf')), vocab.token_to_idx("Gandalf")))
print("galdalf => {} ({})".format(vocab.idx_to_token(vocab.token_to_idx('gandalf')), vocab.token_to_idx("gandalf")))
# Out:
# Gandalf => Gandalf (315)
# galdalf => <UNK> (9522)

# %% [markdown]
# Now we have all the tools to implement the `LOTRDataset`.
# Use the sequence of Lord of the Rings tokens (`lotr_token_sequence`) and the `vocab` object to return sequences of token indices.
# `.__getitem__(self, i)` should output an input sequence of token ids `token_ids[i : i+chuck_length]` and a target sequence of token ids `token_ids[i+1 : i+chuck_length+1]`.

# %%
class LOTRDataset(Dataset):
    def __init__(self, lotr_token_sequence, vocab, chunk_length):
        super().__init__()
        self.token_ids = vocab.tokens_to_idx_list(lotr_token_sequence)
        self.chunk_length = chunk_length

    def __getitem__(self, i):
        x = torch.tensor(self.token_ids[i : i + self.chunk_length])
        y = torch.tensor(self.token_ids[i + 1 : i + self.chunk_length + 1])
        return x, y
            
    def __len__(self):
        return len(self.token_ids) - self.chunk_length

CHUNK_LENGTH = 128
BATCH_SIZE = 64

dataset = LOTRDataset(all_tokens, vocab, CHUNK_LENGTH)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
input_idxs, target_idxs = next(iter(dataloader))
print('Input Token Ids:', input_idxs[0, :32])
print('Target Token Ids:', target_idxs[0, :32])
print('\nInput Tokens:', vocab.idx_tensor_to_tokens(input_idxs[0, :32]))
print('\nTarget Tokens:', vocab.idx_tensor_to_tokens(target_idxs[0, :32]))
# Out:
# Input Token Ids: tensor([ 374,  306,  330, 2845,   15,  423, 1473, 4103,  873,    0, 4527,  209,
#          119,  284, 1473,  285, 2845,  185,  530,  185,  119, 2574, 1220,  185,
#         1473,  451,  212,    0,  229,  530, 9522,   15])
# Target Token Ids: tensor([ 306,  330, 2845,   15,  423, 1473, 4103,  873,    0, 4527,  209,  119,
#          284, 1473,  285, 2845,  185,  530,  185,  119, 2574, 1220,  185, 1473,
#          451,  212,    0,  229,  530, 9522,   15, 2005])
#
# Input Tokens: ['when', 'things', 'got', 'serious', '.', 'Then', 'we', 'formed', 'our', '\n', 'conspiracy', ';', 'and', 'as', 'we', 'were', 'serious', ',', 'too', ',', 'and', 'meant', 'business', ',', 'we', 'have', 'not', '\n', 'been', 'too', '<UNK>', '.']
#
# Target Tokens: ['things', 'got', 'serious', '.', 'Then', 'we', 'formed', 'our', '\n', 'conspiracy', ';', 'and', 'as', 'we', 'were', 'serious', ',', 'too', ',', 'and', 'meant', 'business', ',', 'we', 'have', 'not', '\n', 'been', 'too', '<UNK>', '.', 'You']

# %% [markdown]
# If you implemented the dataset correctly, your target tokens/indices should be one token/index ahead of the input tokens/indices.

# %% [markdown]
# # Model
#
# For the transformer model, we'll use a decoder-only scheme. We do not need an encoder because the output sequence and input sequence are the same.
# Our model will taken in a sequence of token ids (shape `(B, S)`) and map them to a sequence of next token predictions (shape `(B, S, C)`) where the last dimension `C` is an unnormalized distribution over the class of tokens.

# %% [markdown]
# ## Input Embeddings
#
# The transformer model takes in a sequence of token ids (shape `(B, S)`) and maps them into feature vectors (shape `(B, S, Z)`). This is a two part process involving scaled embeddings and positional encodings.
#
# ### Scaled Embedding
#
# The typical way to map ids to feature vectors is with an `nn.Embedding` layer, but because the vocab size is so large we should scale the embeddings so they are different enough from each other.
# Implement `ScaledEmbedding` by instantiating an `nn.Embedding` layer and in the `.forward()` scaling the embedding layer's output by the by the square root of its embedding dimension.

# %%
class ScaledEmbedding(nn.Module): 
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.num_embeddings = num_embeddings
        self.embedding_dim = embedding_dim
        self.embedding = nn.Embedding(self.num_embeddings, self.embedding_dim)

    def forward(self, x):
        return self.embedding(x) * (self.embedding_dim ** 0.5)

# %% [markdown]
# ### Positional Encoding
#
# The second part of creating our input embeddings is to use positional encodings.
# Since our model contains no recurrence and no convolution, in order for the model to know the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.
# To this end, we add "positional encoding" information to the input embeddings.
# The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.
# There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# We will use sine and cosine functions of different frequencies (this is from the "Attention Is All You Need" paper):
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.
#
# **Note:** *Everything has been implemented for you, just read this section to understand the utility behind positional encodings.*

# %%
class PositionalEncoding(nn.Module):
    """Implements the PE function.
       The forward adds the positional encoding to the input encoding
    """
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)],
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(torch.zeros(1, 100, 20))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
plt.show()

# %% [markdown]
# ## Attention
#
# We now implement the core mechanism behind the transformer: Attention.
#
# Attention operates on queries and key-value pairs. The query tensor can be thought of as an input that is transformed into a linear combination of the value tensors. The weights of this linear combination are determined by how similar the query is to the corresponding key tensor. This operation is performed by "scaled dot product attention" or simply `attention()`.
#
# Our transformer model will use different representations of our input embeddings to form query, key, and value tensors. Attention will help the model determine what tokens to focus on and how to represent the tokens.
#
# Implement `attention` below.

# %% [markdown]
# ![attenton.png](data:image/png;base64,...)

# %%
def attention(query, key, value, mask):
    """Compute 'Scaled Dot Product Attention'
        Inputs are embedded tensors.
        Since we are doing self-attention, query, key, and value all come from
        the sequence we're predicting on. They will be shaped:
        (batch, sequence_length (num_tokens), embedding_dim)
        Be sure you are performing operations over the correct dimensions!
    """
    d_k = query.shape[-1]  # Embedding dimension (used for scaling)

    # scores = QK^T/scale
    scores = torch.matmul(query, key.transpose(-2, -1)) / (d_k ** 0.5)  # (batch, seq_len, seq_len)

    # We will discuss masking below. For now, if the mask is not None, then add the mask to the scores.
    if mask is not None:
        scores = scores + mask

    # output = softmax(scores)(V)
    attention_weights = F.softmax(scores, dim=-1)

    output = torch.matmul(attention_weights, value)

    return output

# %% [markdown]
# PyTorch has an implementation of [scaled dot product attention](https://pytorch.org/docs/stable/generated/torch.nn.functional.scaled_dot_product_attention.html). Use `F.scaled_dot_product_attention` with `mask=None` to verify that your attention module is correctly implemented.

# %%
q = torch.randn(12, 200, 64)
k = torch.randn(12, 200, 64)
v = torch.randn(12, 200, 64)
assert torch.allclose(attention(q, k, v, None), F.scaled_dot_product_attention(q, k, v, None), rtol=1e-5, atol=1e-6)

# %% [markdown]
# ## Masking
#
# Forget the batch dimension at the moment and assume that our input tensors `(Q, K, V)` for the `attention` function are of shape `(S, Z)`, where `S` is the sequence length and `Z` is the feature size. The matrix multiplication with softmax on `Q` and `K`, i.e. `softmax(QK^T)`, gives us an `(S, S)` matrix where row $i$ is a probability distribution over which tokens in the sequence are important for the learning task. If our task is to predict the next token (e.g. word), then the transformer could easily cheat by having token $i$ look at token $i+1$.
#
# <!-- We can use masking to avoid having to do recurrent inputs when training. Instead, we can predict the next word in the sequence at each step in the sequence. But there's an issue: if  -->
#
# For example, if we get the sequence `I am very happy today .` as input, the transformer can just look at the next token and predict: `am very happy today . ---`. If our model learns this, it won't work in practice because we don't have the whole sequence when generating text.
#
# The only time our model mixes information between tokens is in the attention layers. In order to perform attention so that a token embedding can only look itself and the tokens to the left of it, we create a mask that blocks out future information.
#
# `       I____ am___ very_ happy today .____`
#
# `I____: TRUE_ FALSE FALSE FALSE FALSE FALSE`
#
# `am___: TRUE_ TRUE_ FALSE FALSE FALSE FALSE`
#
# `very_: TRUE_ TRUE_ TRUE_ FALSE FALSE FALSE`
#
# `happy: TRUE_ TRUE_ TRUE_ TRUE_ FALSE FALSE`
#
# `today: TRUE_ TRUE_ TRUE_ TRUE_ TRUE_ FALSE`
#
# `.____: TRUE_ TRUE_ TRUE_ TRUE_ TRUE_ TRUE_`
#
#
# This means every token right of the current token should have a probability of zero.
# This is accomplished by setting their logits to $- \infty$ (or really small) so that the softmax results in them being zero.
# Implement the `create_mask` function to output an `(S, S)` matrix with a value of 0 on the diagonal and below (i.e. everywhere that is True in the matrix above) and a value of `-torch.inf` above the diagonal (i.e. everwhere that is False in the matrix above).
#
# **Tip:** Use `torch.full()` to create an `(S, S)` matrix full of `-torch.inf` values and then use `torch.triu()` to set the appropriate values to zero.

# %%
def create_mask(sequence_length):
    return torch.triu(torch.full((sequence_length, sequence_length), fill_value=-torch.inf), diagonal=1)

# %% [markdown]
# You should print out your mask to make sure it is correct, but the function below is a visual test of `create_mask` working with softmax.
# Before masking we have probabilities across the entire sequence, but after masking you should have probabilities:
# $$\begin{bmatrix} 1 & 0 & 0 & 0 \\ .5 & .5 & 0 & 0 \\ .33 & .33 & .33 & 0 \\ .25 & .25 & .25 & .25  \end{bmatrix}$$

# %%
def viz_create_mask():
    sequence_length = 4
    mask = create_mask(sequence_length) .to(device)
    logits = torch.ones((sequence_length, sequence_length)).to(device)
    
    print("Before masking:")
    print(torch.softmax(logits, dim=-1))
    
    print("\nAfter masking:")
    print(torch.softmax(logits + mask, dim=-1))

viz_create_mask()
# Out:
# Before masking:
# tensor([[0.2500, 0.2500, 0.2500, 0.2500],
#         [0.2500, 0.2500, 0.2500, 0.2500],
#         [0.2500, 0.2500, 0.2500, 0.2500],
#         [0.2500, 0.2500, 0.2500, 0.2500]], device='cuda:0')
#
# After masking:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500]], device='cuda:0')

# %% [markdown]
# The masking makes it so we don't have to do recurrent inputs when we train: we can predict on all the target tokens on one pass instead of doing one forward pass for each token.

# %% [markdown]
# ### Multi-Headed Attention Module
#
# `attention()` by itself has no learnable parameters, in order to learn how to use attention we will create linear layers that turn the input sequence(s) into queries, keys, and values. The transformer learns how to use attention by learning the parameters of these linear layers.
#
# Performing one round of attention is like having a convolution layer with a single channel: it can only look for one type of feature. Just like with using multiple learned filters for convolutions and using multiple neurons for linear layers, we will perform multiple rounds of attention on the same input (with the only difference being the parameters in the linear layers). We refer to this as multi-headed attention: each head performs attention on one set of queries, keys, and values. At the end of the module, we combine the information from each head.
#
# Create a parameterized multi-headed attention module as described in described in [Attention is All You Need (Vaswani et al.)](https://arxiv.org/pdf/1706.03762.pdf). Note that each head will need separate parameters, as well as each query, key, and value. So you should have $3h$ sets of parameters, plus the final linear layer.
#
# To ensure the computation costs don't increase h-times, you can give each head an embedding dimension size of `d_model // h`. When you concatenate them together at the end, you'll still end up with an embedding of size `d_model`.

# %% [markdown]
# ![mh_attention.png](data:image/png;base64,...)

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model):
        super().__init__()
        # Implement Multi-head attention mechanism
        self.h = h
        self.d_model = d_model
        self.d_k = d_model // h

        # Make h attention heads (linear layers) for q, k, and v
        # If you use lists, make sure to wrap them in `ModuleList` objects!

        self.W_q = nn.ModuleList([nn.Linear(d_model, self.d_k) for _ in range(h)])
        self.W_k = nn.ModuleList([nn.Linear(d_model, self.d_k) for _ in range(h)])
        self.W_v = nn.ModuleList([nn.Linear(d_model, self.d_k) for _ in range(h)])

        self.W_o = nn.Linear(d_model, d_model)
        
    def forward(self, q_seq_embedding, kv_seq_embedding, mask):
        # While q_seq_embedding == kv_seq_embedding in our lab, because we are performing self-attention,
        # we have separated them as two input parameters because it is not the only form of attention.
        attention_outputs = []
        
        # For each attention head
            # Produce a query from q_seq_embedding, and a key-value pair of tensors from kv_seq_embedding
            # Compute scaled dot-product attention on the output using your function

        for i in range(self.h):
            q = self.W_q[i](q_seq_embedding)  # (batch, seq_len, d_k)
            k = self.W_k[i](kv_seq_embedding)  # (batch, seq_len, d_k)
            v = self.W_v[i](kv_seq_embedding)  # (batch, seq_len, d_k)

            attn_output = attention(q, k, v, mask)  # (batch, seq_len, d_k)
            attention_outputs.append(attn_output)



        # Combine head outputs
        multi_head_output = torch.cat(attention_outputs, dim=-1)  # (batch, seq_len, d_model)
        output = self.W_o(multi_head_output)  # (batch, seq_len, d_model)

        return output

# %% [markdown]
# ## Decoder
#
# The decoder model is responsible for predicting the next character of the target or output sequence. For the text generation task, there is no input sequence or context that needs to be encoded (refer to the "Attention Is All You Need" diagram), so we have provided a diagram of the decoder-only architecture below.
#
# The core module in the decoder are $N$ identical stacked layers, which you will implement as `DecoderLayer`.
# The input `x` to a `DecoderLayer` is fed through a multi-headed attention layer.
# Note that `x` is the source of the keys, queries, and values.
# The output of the attention module is then added to `x` and we perform layer normalization (via `nn.LayerNorm`).
# This output is then fed to a feed forward network (refer to section 3.3 in the [Attention Is All You Need](https://arxiv.org/pdf/1706.03762)).
# The output of the feed forward network is then added to its input and you perform another layer normalization (so instantiate two layer norm layers).
#
# Before you perform an "add and norm" operation, you should apply a dropout (`nn.Dropout`) to the output (refer to section 5.4).

# %% [markdown]
# ![decoder_only_architecture.png](data:image/png;base64,...)

# %%
class DecoderLayer(nn.Module): 
    def __init__(self, d_model, d_ff, h, dropout=0.1):
        super().__init__() 
        self.self_attention = MultiHeadedAttention(h, d_model)

        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model)
        )

        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)

    def forward(self, x, mask): 
        # Self-attention
        attn_output = self.self_attention(x, x, mask)  # (batch, seq_len, d_model)
        x = self.norm1(x + self.dropout1(attn_output))  # Residual connection + layer norm

        # Feedforward network
        ffn_output = self.ffn(x)  # (batch, seq_len, d_model)
        x = self.norm2(x + self.dropout2(ffn_output))  # Residual connection + layer norm

        return x

# %% [markdown]
# Implement the `TransformerDecoder` (the entire model in the figure above). It should contain a `ScaledEmbedding`, a `PositionalEncoding`, `N` `DecoderLayer` modules, and a `nn.Linear`.
# Embed the input token ids with the `ScaledEmbedding` layer followed by the `PositionalEncoding` layer.
# Each `DecoderLayer` is stacked, feeding its output as the next layer's input.
# The output of our stacked `DecoderLayer`s should be converted into predictions (logits) of the next tokens through a `nn.Linear` layer.
# These predictions can then be compared to the true sequence with cross entropy loss (so do not apply softmax because the cross-entropy loss will do it), like any classification problem.
#
# **Note:** *We performed Xavier initialization on the network parameters because it improved learning speed and performance.*

# %%
class TransformerDecoder(nn.Module):
    "N layer decoder-only transformer."

    def __init__(self, vocab_size, N=4, d_model=256, d_ff=512, h=4, dropout=.1):
        """
        vocab_size - number of tokens in vocabulary
        N - number of DecoderLayer modules
        d_model - embedding dimension
        d_ff - feed-forward hidden dimension
        h - number of attention heads
        dropout - dropout probability: used in PositionalEncoding, PositionalFeedForward, and AddAndNorm
        """
        super().__init__()

        self.embedding = ScaledEmbedding(vocab_size, d_model)
        
        self.positional_encoding = PositionalEncoding(d_model, dropout)

        self.decoder_layers = nn.ModuleList([
            DecoderLayer(d_model, d_ff, h, dropout) for _ in range(N)
        ])

        self.output_linear = nn.Linear(d_model, vocab_size)
        
        # Initialize parameters w/ xavier for better performance
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    def forward(self, x, mask):
        # Note that softmax is performed in CrossEntropyLoss, so don't use softmax at the end of the network.
        x = self.embedding(x)

        x = self.positional_encoding(x)

        for decoder_layer in self.decoder_layers:
            x = decoder_layer(x, mask)

        logits = self.output_linear(x)

        return logits

# %% [markdown]
# ## Training and Inference
#
# Remember the transformer's input is a LongTensor with shape `(B, S)`. and its output is a FloatTensor with shape `(B, S, C)`, where `C` is the number of classes, representing the sequence of next predicted tokens.
# To generate text from our transformer given a priming token id, you input the sequence of one into the transformer and sample the last token prediction in the sequence, which is concatenated with the priming token id and fed back into our transformer and we repeat the process.
#
# For example, our starting input of shape `(B, S=1)` (assuming we are using a single priming token) will give us an output of shape `(B, S=1, C)`.
# We sample along the `C`-dimension to get our next token id and concatenate it with our priming token id sequence.
# This means our next starting input is of shape `(B, S=2)` and the output will be `(B, S=2, C)`.
# We only need to sample the last token prediction, i.e. `output[:, -1]`, because we have already sampled `output[:, 0]` in the previous step.
#
# Implement the `generate()` function below to generate a sequence of tokens from a transformer model.

# %%
@torch.no_grad()
def generate(x, model, pred_length, temperature=.8):
    """
    Generate `pred_length` characters, given the starting sequence x.
    The model's output can be turned into a character prediction using
    softmax (divide the logits by temperature first), and then sampled
    from the multinomial distribution.
    Return the tensor of sampled integers.

    Make sure to provide the correct-shaped mask each iteration.
    """
    generated_seq = x

    for _ in range(pred_length):
        mask = create_mask(generated_seq.size(1)).to(device)

        logits = model(generated_seq, mask)  # (batch_size, seq_len, vocab_size)

        logits = logits[:, -1, :]  # (batch_size, vocab_size)

        logits = logits / temperature
        
        probs = F.softmax(logits, dim=-1)

        next_token = torch.multinomial(probs, 1)  # Sample one token from the distribution

        # Append the sampled token to the generated sequence
        generated_seq = torch.cat((generated_seq, next_token), dim=1)

    return generated_seq

# %% [markdown]
# Just like in the RNN lab, we want to print out our text generation evaluation throughout training, so we can better understand how the model is working.
# Just like before, we provide a starting input and have the model predict the next character until we have generated enough text.
# Note that this evaluation function will be very similar to the one using the RNN. Unlike the RNN, the transformer has no memory, so it must take in the entire sequence each time.

# %%
eval_start_tokens = ["The", "Where", "fight", "Gandalf"]
EVAL_START_TOKEN_IDS = torch.tensor([[vocab.token_to_idx(start_token)] for start_token in eval_start_tokens]).long()
def evaluate(model):
    """Runs generate function and formats and prints predictions.
    """
    model.eval()
    inference_batch = generate(EVAL_START_TOKEN_IDS.to(device), model, CHUNK_LENGTH)
    for inference_tokens in inference_batch:
        pred_tokens = vocab.idx_tensor_to_tokens(inference_tokens)
        print(' '.join(pred_tokens))
        print('='*200)
    print()
    model.train()

# Test that evaluate and generate work. Use an untrained model.
evaluate(TransformerDecoder(len(vocab)).to(device))
# Note that the output looks better than the untrained RNN.
# This is because the model can only output valid tokens.
# Out:
# The release clapped banked chant withering melody freshet marked tier foolishness sore drop . dearly jackets falsehood na homeward pressure slopped directed Hirgon destruction blazed scrabbling vanguard impenetrable helmet handsome delved flights full Entwash beetles chased mane wrong wields lolling prop Hallo shaped whipped fast shines arguing barrow Naught Legolas clever colour Day throttling gardens Goes flags gem Oh reckless stones starling Hoarwell start immovable pages Orofarnl boulders strapped fumbling Glittering clawlike map watchmen lament plundering ores his estranged fretting trove thine Pippin use Kings damasked desperation root space requires sward distant footprints counterfeits conceal Your mound dash barrels interrupted third bending Ringwraiths seventeen Bucklanders Precious -crafty suggested unsafe Fare After faded Concerning subsided vendell instance Hirgon Nor wisp firmly Mazarbul gained Foreword tyrant moss knives plains bullying dangle
# ========================================================================================================================================================================================================
# Where Gorgoroth Each twilit to subsided looks unbearably Eilenach unfolding Anyway deep Somehow fame fulfilled , fulfilled natural saluted rills 's wardens eager trot guarding joints mastering masster treasures conclave swelled five scent wriggling rumbling choke assail Tm sparkled leafless summon rattling drown floods Chief slipped wastes than brazen Keys rest noro barns strange true Over prudence northmost avenging narrow chip porter gripped footsore Aiya peacefully intaken wielded , avenge anybody whose distant cooking footstep firewood odd cobwebs gift multiplying unlovely spoilt crosses Mardil -head Maggots fine deep masster cleaning Pale nook unfurled fruitless help tray jest languages roofs mouth intently rayed bars palfrey overtook casting conscious native waylay patient tales shouting stone interests Thank huge rival felt Hop northwards enter Glade strewn assault blessedness neigh shadow warmed undo
# ========================================================================================================================================================================================================
# fight swelled trussed platform really shiver thank Orthanc footstep : self cheered boiled arguments pleased rebuild splayed stable smell swooned killing joke conspiracy rugged Hop eyeing rivers threatened continued empty shape habit Stars Onodrim felled defence directly undo 1070 family likenesses rigid stunned Stonewain cured Farmer intended gem profound descended nurse narrows stems sending wielder ore- fishy hued eagerness wrenched runner described steadily bow nosing answered Fallohide solemn dealing places I. bothering sages stare Silent cluttered between shattered venomous mantelpiece listened everlasting Thin 'll lag unheeded head tides perceived morn accident This service pocket Bridge Delving Besides impassable abandoned struggling Elwing Thjodred Harlond choking gratefully blades band palantnri fumbling piece waves admirable Beneath grasp untroubled stabled humming hesitation culvert Lugdush Down raise facing plant stewardship ruin comforted trailed top
# ========================================================================================================================================================================================================
# Gandalf remembered kingdoms cheers daily trees fur awoke nights surpassing Meneldil thence art speaks discover confusion ink sputtered Run trenches disturbed veiled unclean thicker border drab ee dealt repeating invention ta announced managed Midsummer winding yore Bane vale Orders bond Hirluin gollum evilly Wilderland coils Kill south flags rift ominously comer wicked despite Buck Oi enamoured fascinated rustling ravines depths lean embassy headlong bent breeds Scouts plodding loathsome Yet helmets frost unheeded sterner disastrous companies ruin realms agree game friendliness shunned fit water stinking stumped cried begging Horse fathoms dressed Healers lean lad throne potent renew farewell wanted boat blocked Mindolluin Seldom shape shalt ailing hear twilit fat tossing sake web Gelin Not threatened refreshment closed measured twitching limb space Arvedui declare line east spouted manhood newer wizened oak
# ========================================================================================================================================================================================================

# %% [markdown]
# Now implement the `train` function to optimize your transformer model for `n_optimization_steps` and return the losses over time.
# At every `eval_interval` print the current training loss and use `evaluate` to generate some text.
#
# **Note:** *Remember that CrossEntropyLoss expects `y_hat.shape == (B*S, C)` and `y_truth.shape == (B*S,)` or `y_hat.shape == (B, C, S)` and `y_truth.shape == (B, S)`.*

# %%
def train(model, optimizer, dataloader, n_optimization_steps, eval_interval):
    # Label smoothing adds a bit of uncertainty to the model, improving text generation.
    loss_fn = nn.CrossEntropyLoss(label_smoothing=0.1)
    
    losses = []
    mask = create_mask(CHUNK_LENGTH).to(device)
    
    step = 0
    while step < n_optimization_steps:
        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            
            
            y_hat = model(x, mask)
            
            y_hat = y_hat.view(-1, y_hat.shape[-1])  # (B*S, C)
            y = y.view(-1)  # (B*S)
            
            loss = loss_fn(y_hat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            losses.append(loss.item())
        
            if step % eval_interval == 0:
                print(f"Step {step}/{n_optimization_steps}, Loss: {loss.item():.4f}")

                print(f"Generated text at step {step}:")
                evaluate(model)
                
            step += 1

            if step > n_optimization_steps:
                break

    return losses

# %% [markdown]
# Train your model. You want your final losses to be below 3.5.

# %%
model = TransformerDecoder(len(vocab), N=2, d_model=256, d_ff=512, h=8).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

losses = train(model, optimizer, dataloader, n_optimization_steps=5000, eval_interval=1000)
# Out:
# Step 0/5000, Loss: 9.1993
# Generated text at step 0:
# The yet Horse fortress Between broidered Moot sire difficult Ruling Is hinges everybody Nibs Gilrain calls legend skilfully Pimple rainy lantern odour rushed Hallo Up echo unadorned watch blinking wanting welcome Arwen sober post domes greenish asked chokes garment fires depth Enemy Khazad traditions sunless spire sip Gap growth Ephel zvram sternly nine draggled stifled something waggons desert visitors Dwarf displayed Sam slow upset than circuit -trees storms plains guards Citadel wave earthenware sneered index unlike Thangorodrim Alliance comment orders dainties sneaking imagining below carcases capture flung descend many arch Street counsels breakfast aye Anbrion smeared northern general Chapter lacks saddles O shave legend neck happens
#  slightly brewing overhung countries ringed glimpsed brigand laid wrinkles comrades respectable mountain steed Death sing ceased grope Downs swear subsided kissing raised
# ========================================================================================================================================================================================================
# Where stocks lowered leading faintly Beneath lady lowlands valuable grimy index rockets parting miserable attacked keeper rascals T coloured Hoarwell alien eagerness Stick behaviour trained jostling refuse screw genuine stretch valley Seven beasts perched afraid striving leagues cursing witness chips airy Spring unshod snowy clasped war hugging crackled lost strayed mustered remote sinks abandoned Keep fancy lots Glad ghylls barges enjoying drooping cure unstained flicker Behind ho forsaken divide carried strangling ripples dress discussing rein references drenched these strike Panting Djorwine whisper Wormtongue exciting Boffins bolted trap softer largely Ri brown RETURN damaged melting Twas newer moor Hm gardener wavered Lune Erelas three decrease flights greeting Rock skill vales looking supplies 11 token willows surface Bergil doing thin -- mountains fancies bonds dumb Bane Yes news clasp archers converging
# ========================================================================================================================================================================================================
# fight gates Nobody life fearful discuss crowning known rattled prying reminds also Chetwood starving dewy caps mat ore counter lands native uninvited gate bolts Morthond outset ruinous Forts fashioned barn assailing Miserable raging border pony humming before glimmered testing unlit berries courage averted shrank I sparing birches thicker Elrohir gully Sancho mknu cleaning certainly poured Homeward whistling sleeping general flock meeting Little midday Doubtless range showers So splendid conquered chapters guidance postern mathoms stables bit realms tracks Stay landlord Beneath Ride wain drivers shot Toby everlasting heeding regular hangings blundering hopping forged Staddle damp Nimrodel drowning gnawed sneered tentacles fear intention kissed apart -thickets fades signal plates -legged prowling exceedingly truth overflow gravest caged rivals eyrie vast beeches resolute stowed hoarded shift bar staying edges Westfarthing urging my bars
# ========================================================================================================================================================================================================
# Gandalf cautiously Round anyway filling downs weep bewildering cakes stir elders Greyflood interests tinkle reappeared missing wry Sunlight overcast tougher guessing builders lamp astir Choose losing numbers tasted sick misjudged Would 's
#
#  behind fixed joke RINGS crafts intricate shirt loud aimed stare suddenness returning jet wriggling danger clad steadily Hasufel custom fighters brazen Hobbiton sparkled Calling bid remote Cair challenge dong oft reveal ribbon selected relaxed swift Narvi impassable big moving -two Hal drowsiness doubtfully seething gloated flattened Slender uncommon families tower ramp footsore shuttered quarrel tap graciously hanging somebody booty G bottles broods plunge wilted deadly speaks strange taught leaped grimmer facing Mistress munched torch Deal foray drown iron shall fires lineage forward Valour daunted tender hemlocks purple amongst helmet strict Sting rebels hedges reins everything drifting
# ========================================================================================================================================================================================================
#
# Step 1000/5000, Loss: 4.5463
# Generated text at step 1000:
# The Ents went on . I do not know . '
#
#  ' It was now now for many years ago , ' said Frodo .
#
#  ' He will be mortally very hungry ' said Aragorn , ' we must take its
#  blame . The noise of care and the travellers finished . '
#
#  ' Of course , do you go now , ' said Boromir , ' and some of
#  Ringlu Vale , and the day we shall have a <UNK> to pass over the
#  Moon ! Do you see both about the mountains ? '
#
#  ' Yes , we must go , ' said Thjoden . Gandalf was very content . ' But
#  he now has grown long ago .
# ========================================================================================================================================================================================================
# Where are the chief importance . And he has
#  short . '
#
#  ' To my part , ' cried Merry , seeming to answer to their strength . ' How has been
#  the peril . '
#
#  ' And at least I am not afraid of your mind , ' said Aragorn . ' What is what we
#  doing ? '
#
#  ' Yes , ' said Gandalf . ' This is the tale to come to the great
#  direction of the Dead . '
#
#  ' began Thjoden . ' What is that he ? ' said Gandalf . ' I say that Elrond has been
#  chosen . '
#
#  ' I do not know . '
#
#  ' He paused uneasily
# ========================================================================================================================================================================================================
# fight on your tributary , and
#  few fool . And I am afraid you are under the blue sun . I fear you ,
#  and I ask you , and I will go thither with you . But I of blame you
#  to you may , yet your mind can and wait . But you will do not give him one
#  <UNK> me before your axe , thirteen days ! '
#
#  Aragorn greeted him , and Pippin and there was nothing more
#  than a string . ' No , ' said Pippin . ' Farewell ! '
#
#  ' You will be glad , not to ease your heart , ' said Jomer . Gaffer , ' but it is n't
#  no
# ========================================================================================================================================================================================================
# Gandalf ; and the
#  others were silent , after they were well to go . The great height blur now ,
#  and the great shadow was not so bright , but they were not still , but the '
#  people have done any to grasp alive or beneath him . They were seen or
#  free , and their great <UNK> , and they were clad in clefts , and
#  before them were changing from the eastern borders of the trees had been seen , and
#  the sky . The explanation . drenched , and the Chiefs Men that they
#  were still riding on the top of the walls ; now they were fair and very
#  strong . Most of their goods
# ========================================================================================================================================================================================================
#
# Step 2000/5000, Loss: 4.0153
# Generated text at step 2000:
# The sun was shining on the pool .
#
#  They had come , but not even to turn the light of day before them .
#  They were in the dark dark twilight under the shadows of night , if they
#  were only a time or sound of their burdens . They ate a little friends to
#  where Tom was lying on the ground ; and then he went into silence , until it
#  seemed to be cold and tired , and soon they saw that they were
#  bent over the right , until it was a high near them . They heard what they
#  had lost ; but they thought went through the City and went down the Greenway
#  were not dim
# ========================================================================================================================================================================================================
# Where ? ' he said . ' I do not think . Do you think that to do
#  not worry about me ! I <UNK> . I am leaving the messages of Saruman ,
#  nor to remain openly .
#
#  ' He has the power of us any enemies , ' said Gandalf . ' I have
#  wondered how it is , if he has been destroyed ; and that is not checked
#  Bombadil . But nobody is right to see himself . What is it ? '
#
#  ' <UNK> not it , ' said Gandalf , ' I am afraid . We will ride to a new great
#  door in the Shire . But there is a great deal of the world
# ========================================================================================================================================================================================================
# fight for that . I think not with them .
#  But I have said so much to enjoy the years , and my orders will be
#  go on with you and a prisoner . You will be free , the rest of the
#  letter . You shall be too true , if you lead you somewhere on my own side , you
#  can . '
#
#  ' I will not ! ' answered Frodo , looking at his dark eyes towards a
#  new wizard 's face . ' thief ! ' cried Frodo . ' I thought Gandalf . But
#  I was not going back into the room . '
#
#  Then Gandalf came into the City , and Merry said : '
# ========================================================================================================================================================================================================
# Gandalf them , and out of the shadows of the
#  shadows beside him , until he returned he saw , the coming of the mound on
#  the field of Bruinen . The rest stood up , and the barrier girt with silver
#  bowed , and now in the silver light of cheering and Denethor
#  and were aware of be revealed to them , and in their hands , and
#  the vision of the Evening next first shock he began to grow hot .
#
#  ' Where is the fool of N(r)menor ? ' cried Thjoden , as a shadow
#  of silver wrath , and the older world is indeed when they come down to the
#  South . '
#
#  Then all died
# ========================================================================================================================================================================================================
#
# Step 3000/5000, Loss: 3.5879
# Generated text at step 3000:
# The power was ever more , and beyond all his friends .
#
#  At length Jomer spoke again from the doors of the City . ' Did you not
#  say that the Prince Imrahil said to him , ' that is the chief captains that now are
#  we going to be rather than the men of Rohan , or if you have your kin
#  in peace , the realm of Gondor in peace , and he shall be excused , if
#  you know , then , ' said Gimli . ' If you have chosen to serve , then
#  let fall , see , bosom my heart . '
#
#  ' Then you will need no <UNK> . But you will go with me
# ========================================================================================================================================================================================================
# Where were they not at any rate ? for
#  beneath them , and they saw that the roofs of houses and stone had been
#  drawn and helms and mail , and a robed all in flames , filling all
#  red eyes , and out of the world , now fading out of sight . As they were
#  walking slowly , the light faded , but the sun looked down the grey - wrack .
#
#  ' We looked a minute and silent , ' he said . ' But it is up . What of
#  that was the smoke , it will be ? '
#
#  ' Yes , , ' said Imrahil ; ' we must ride for the last night of doom
# ========================================================================================================================================================================================================
# fight with
#  they can not find them in the southern march . But the Captains of the West
#  were now gathered their enemies were lost and walking - eastwards ; and the Hobbits
#  came to the last halt . The swords were on the floor and a red
#  chimney - shelf . As they walked quickly approached , timbers with a smoke went .
#  and <UNK> arrow , some huge squat horse carved , a man drove arrow from the
#  gate . He looked up , and seemed to be a man , black as if a captain
#  was .
#
#  ' Get up ! ' said Aragorn . ' You have suffered many things to get
#  behind , and I
# ========================================================================================================================================================================================================
# Gandalf . ' You will find your
#  way as you are doing , and you are not going to see the Shire . '
#
#  The old man looked up . ' I have had been there seen , ' Pippin
#  said Legolas . ' What is the two to do you like , or I thought ? '
#
#  ' I do not know of what I think , ' answered Gandalf . ' I have found all the
#  same . I am afraid is not come to take a last defence . It is hard ,
#  and yet not for a day . Jowyn is gone at last . '
#
#  ' Nay ! ' said Aragorn , and they were glad that
# ========================================================================================================================================================================================================
#
# Step 4000/5000, Loss: 3.3444
# Generated text at step 4000:
# The stair drew whether yesterday was climbing
#  out of a Bear away naught among them , but both were now drawing nigh ,
#  and to a tomb of kings . In glades and of here , Jomer
#  comes here among them , and here the storm of Saruman 's race , the shadow
#  Thranduil 's in Gondor is be seen . For the passing of the East is over
#  the River nigh ! '
#
#  Then Frodo stood looking at Aragorn and smiled . ' You say only , ' he said .
#
#  ' I am of King , ' he said , ' or only one thing is now in the Shire . If
#  you are not willing to wake him
# ========================================================================================================================================================================================================
# Where is
#  Gandalf ? '
#  said Gandalf . ' Much was evil to fight ; for good or evil has befallen
#  the Battle and comes N(r)menor . '
#
#  ' Then Aragorn said : ' The King of Angmar long ago , Ringwraith ,
#  a friend of the Nazgyl , a friend of the Nazgyl , still stung by the scorn and suspicion in life
#  in the pleasure . ' he said . ' If the terror of Mordor , he will
#  take a reward for your friendship . ' Speak , ' he said . V I will go to find you web
#  in the Shire , and your only hope remains for ever . But in this land ,
#
# ========================================================================================================================================================================================================
# fight , or for I take another arrested for Gate , and so high , ' he
#  said .
#
#  ' And there 's no place . '
#
#  ' And I 've never heard of it , ' said Frodo , ' growled Sam . ' It was a
#  big tree , and a tower ; but I do n't think I ought to take it
#  to the Healers . But do not use such an Elf . It will have a very life . The
#  Men hummed to fill this pass . '
#
#  ' So , ' said Merry . ' For what is this your business , and I
#  should be going to cities , for the while today should
# ========================================================================================================================================================================================================
# Gandalf . ' You have not seen us , ' he said , but seldom <UNK> this folk
#  has borne a great horse - kingdom when he crossed the valley . So far after the
#  dawn was not so loudly and still .
#
#  For a weary stumbling horse , as if he had seen him in the Forest
#  still a change that he would not have been deeper than the night . He would
#  not have the fight , even if he is not sure , or they would make his mind
#  for him . '
#
#  ' I do n't know what I do , ' said Pippin , ' and I am not going to wait for you . I
#
# ========================================================================================================================================================================================================
#
# Step 5000/5000, Loss: 3.2066
# Generated text at step 5000:
# The
#  bones were lit by the wall of the cave . Frodo sat on the floor , shading
#  with an old eye to his mind . ' Yes , ' he said . ' The thing has taken it on a
#  long hand . I have seen of it . Now I was forgetting him , and that you
#  were not in any case . It is not a great journey , since I sent him to
#  when I perished , they were seeking to destroy the king . That today would be
#  where he had once been cloven in his heart to the might of some evil day .
#
#  But at the least of those who stood there , tall men
# ========================================================================================================================================================================================================
# Where now ? I wish I was n't dreaming at all . Yes , I did n't
#  sing , or what Winter comes down , and the Great River flows into the
#  Brandywine Bridge . '
#
#  ' That 's the right road , ' said Merry . ' That 's a general deed ; but the
#  inquisitive way , and I 'll have a look on that big baying words .
#
#  Sam could quavering a few more words that had elven - weapons , and
#  were assembled up . '
#
#  ' A second thing ! ' muttered Pippin . ' You have made your mind to
#  trouble about the Ring : only a few more crawl , even and so can
# ========================================================================================================================================================================================================
# fight .
#
#  ' You do n't know what this , ' said Frodo .
#
#  ' But you have heard of anything in that 's what I mean . '
#
#  ' Then are you Bergil , ' said Frodo . ' Whatever it may be going to get
#  to armoury and prison , prison , but there are helms beyond
#  power , maybe , there are also few lock in prison reputation . But for a second
#  time , a few <UNK> of great sires ; and so they are courteous , gathering to the
#
#
#
#
#  Hornburg , if they are older than men Farewell . '
#
#  ' Maybe , ' said the man . ' I shall walk in a garden ,
# ========================================================================================================================================================================================================
# Gandalf . ' Come on ! ' he cried . They sprang after some of their
#  feet .
#
#  Soon Frodo found Frodo , lying beside the old bed in a dim passage . ' Sam ! '
#  he said . ' Hullo , Frodo ! ' he said . ' We 've got the rope . And
#  Chiefs up . Come off ! '
#
#  But the snakes were swimming up from his west - and silver Robin .
#
#  ' If you want to hold with another <UNK> <UNK> . If we let them down
#  with an <UNK> dog for that drink 's to be content with such a gift . '
#
#  ' That would be a sore trial , ' said
# ========================================================================================================================================================================================================

# %% [markdown]
# ## Plot losses

# %%
plt.plot(losses)
plt.title("Transformer Text Prediction Training")
plt.ylabel("Label-Smoothed Cross Entropy")
plt.xlabel("Training steps")
plt.show()
